# %%
import numpy as np
from numpy import linalg as LA

# %%
a = np.array([3, 5])
V = np.array([
    [1, 9], 
    [2, 0],
    [1, 7]
    ])

np.dot(a, V.T)
# Out:
# array([48,  6, 38])

# %%
V / LA.norm(V, axis=1, keepdims=True)
# Out:
# array([[0.11043153, 0.99388373],
#        [1.        , 0.        ],
#        [0.14142136, 0.98994949]])

# %%
def closest_to_antigrad(grad, vectors): 
    sim = np.dot(grad, vectors.T)
    return sim.argmin()

# %%
closest_to_antigrad(a, V)
# Out:
# np.int64(1)

# %%
 % 1 == 0
# Out:
# True

# %%
A = np.array([
    [2, 2, -2],
    [5, 1, -3],
    [1, 5, -3]
])

# %%
np.mean(A, axis=0)
# Out:
# array([ 2.66666667,  2.66666667, -2.66666667])

# %%
np.std(A, axis=0).astype(int)
# Out:
# array([1, 1, 0])

# %%
A_normed = ((A - np.mean(A, axis=0)) / np.std(A, axis=0)).astype(int)
# Out:
# /var/folders/3s/q58jyd3x2_vbrvv36msymj600000gn/T/ipykernel_26044/3157054979.py:1: RuntimeWarning: divide by zero encountered in divide
#   A_normed = (A - np.mean(A, axis=0)) / np.std(A, axis=0).astype(int)

# %%
A_normed
# Out:
# array([[-0.66666667, -0.66666667,         inf],
#        [ 2.33333333, -1.66666667,        -inf],
#        [-1.66666667,  2.33333333,        -inf]])
